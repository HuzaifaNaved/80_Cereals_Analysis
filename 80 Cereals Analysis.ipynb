# %% [markdown]
# # 80 Cereals Analysis

# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Load dataset

# %%
df = pd.read_csv('cereal.csv')

# %% [markdown]
# ## Data Exploration & Cleaning

# %%
df
# Out:
#                          name mfr type  calories  protein  fat  sodium  fiber  \
# 0                   100% Bran   N    C        70        4    1     130   10.0
# 1           100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                    All-Bran   K    C        70        4    1     260    9.0
# 3   All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4              Almond Delight   R    C       110        2    2     200    1.0
# ..                        ...  ..  ...       ...      ...  ...     ...    ...
# 72                    Triples   G    C       110        2    1     250    0.0
# 73                       Trix   G    C       110        1    1     140    0.0
# 74                 Wheat Chex   R    C       100        3    1     230    3.0
# 75                   Wheaties   G    C       100        3    1     200    3.0
# 76        Wheaties Honey Gold   G    C       110        2    1     200    1.0
#
# ...

# %%
df.head(10)
# Out:
#                         name mfr type  calories  protein  fat  sodium  fiber  \
# 0                  100% Bran   N    C        70        4    1     130   10.0
# 1          100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                   All-Bran   K    C        70        4    1     260    9.0
# 3  All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4             Almond Delight   R    C       110        2    2     200    1.0
# 5    Apple Cinnamon Cheerios   G    C       110        2    2     180    1.5
# 6                Apple Jacks   K    C       110        2    0     125    1.0
# 7                    Basic 4   G    C       130        3    2     210    2.0
# 8                  Bran Chex   R    C        90        2    1     200    4.0
# 9                Bran Flakes   P    C        90        3    0     210    5.0
#
#    carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# ...

# %%
df.tail(10)
# Out:
#                        name mfr type  calories  protein  fat  sodium  fiber  \
# 67                Special K   K    C       110        6    0     230    1.0
# 68  Strawberry Fruit Wheats   N    C        90        2    0      15    3.0
# 69        Total Corn Flakes   G    C       110        2    1     200    0.0
# 70        Total Raisin Bran   G    C       140        3    1     190    4.0
# 71        Total Whole Grain   G    C       100        3    1     200    3.0
# 72                  Triples   G    C       110        2    1     250    0.0
# 73                     Trix   G    C       110        1    1     140    0.0
# 74               Wheat Chex   R    C       100        3    1     230    3.0
# 75                 Wheaties   G    C       100        3    1     200    3.0
# 76      Wheaties Honey Gold   G    C       110        2    1     200    1.0
#
#     carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# ...

# %%
df.shape
# Out:
# (77, 16)

# %%
# data types of columns
df.dtypes
# Out:
# name         object
# mfr          object
# type         object
# calories      int64
# protein       int64
# fat           int64
# sodium        int64
# fiber       float64
# carbo       float64
# sugars        int64
# potass        int64
# vitamins      int64
# shelf         int64
# weight      float64
# cups        float64
# rating      float64
# dtype: object

# %% [markdown]
# ### Checking missing values

# %%
pd.isnull(df).sum()
# Out:
# name        0
# mfr         0
# type        0
# calories    0
# protein     0
# fat         0
# sodium      0
# fiber       0
# carbo       0
# sugars      0
# potass      0
# vitamins    0
# shelf       0
# weight      0
# cups        0
# rating      0
# dtype: int64

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77 entries, 0 to 76
# Data columns (total 16 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   name      77 non-null     object
#  1   mfr       77 non-null     object
#  2   type      77 non-null     object
#  3   calories  77 non-null     int64
#  4   protein   77 non-null     int64
#  5   fat       77 non-null     int64
#  6   sodium    77 non-null     int64
#  7   fiber     77 non-null     float64
#  8   carbo     77 non-null     float64
#  9   sugars    77 non-null     int64
#  10  potass    77 non-null     int64
#  11  vitamins  77 non-null     int64
#  12  shelf     77 non-null     int64
#  13  weight    77 non-null     float64
#  14  cups      77 non-null     float64
#  15  rating    77 non-null     float64
# dtypes: float64(5), int64(8), object(3)
# memory usage: 9.8+ KB

# %%
df.describe()
# Out:
#          calories    protein        fat      sodium      fiber      carbo  \
# count   77.000000  77.000000  77.000000   77.000000  77.000000  77.000000
# mean   106.883117   2.545455   1.012987  159.675325   2.151948  14.597403
# std     19.484119   1.094790   1.006473   83.832295   2.383364   4.278956
# min     50.000000   1.000000   0.000000    0.000000   0.000000  -1.000000
# 25%    100.000000   2.000000   0.000000  130.000000   1.000000  12.000000
# 50%    110.000000   3.000000   1.000000  180.000000   2.000000  14.000000
# 75%    110.000000   3.000000   2.000000  210.000000   3.000000  17.000000
# max    160.000000   6.000000   5.000000  320.000000  14.000000  23.000000
#
#           sugars      potass    vitamins      shelf     weight       cups  \
# count  77.000000   77.000000   77.000000  77.000000  77.000000  77.000000
# mean    6.922078   96.077922   28.246753   2.207792   1.029610   0.821039
# std     4.444885   71.286813   22.342523   0.832524   0.150477   0.232716
# ...

# %%
df.describe(include = 'object')
# Out:
#              name mfr type
# count          77  77   77
# unique         77   7    2
# top     100% Bran   K    C
# freq            1  23   74

# %%
# column names
df.columns
# Out:
# Index(['name', 'mfr', 'type', 'calories', 'protein', 'fat', 'sodium', 'fiber',
#        'carbo', 'sugars', 'potass', 'vitamins', 'shelf', 'weight', 'cups',
#        'rating'],
#       dtype='object')

# %%
df.count()
# Out:
# name        77
# mfr         77
# type        77
# calories    77
# protein     77
# fat         77
# sodium      77
# fiber       77
# carbo       77
# sugars      77
# potass      77
# vitamins    77
# shelf       77
# weight      77
# cups        77
# rating      77
# dtype: int64

# %%
# Calculate the market share of each manufacturer based on the number of cereals they produce.
df.mfr.value_counts()
# Out:
# K    23
# G    22
# P     9
# Q     8
# R     8
# N     6
# A     1
# Name: mfr, dtype: int64

# %% [markdown]
# - K = Kelloggs
# - G = General Mills
# - P = Post
# - Q = Quaker Oats
# - R = Ralston Purina
# - N = Nabisco
# - A = American Home Food Products

# %%
# number of hot and cold cereals
df.type.value_counts()
# Out:
# C    74
# H     3
# Name: type, dtype: int64

# %% [markdown]
# - C = Cold
# - H = Hot

# %%
# get min and max contents of the nutritions
nutritional_cols= ['protein','fat','sodium','fiber','carbo','sugars','potass','vitamins','calories']
df[nutritional_cols].describe()
# Out:
#          protein        fat      sodium      fiber      carbo     sugars  \
# count  77.000000  77.000000   77.000000  77.000000  77.000000  77.000000
# mean    2.545455   1.012987  159.675325   2.151948  14.597403   6.922078
# std     1.094790   1.006473   83.832295   2.383364   4.278956   4.444885
# min     1.000000   0.000000    0.000000   0.000000  -1.000000  -1.000000
# 25%     2.000000   0.000000  130.000000   1.000000  12.000000   3.000000
# 50%     3.000000   1.000000  180.000000   2.000000  14.000000   7.000000
# 75%     3.000000   2.000000  210.000000   3.000000  17.000000  11.000000
# max     6.000000   5.000000  320.000000  14.000000  23.000000  15.000000
#
#            potass    vitamins    calories
# count   77.000000   77.000000   77.000000
# mean    96.077922   28.246753  106.883117
# std     71.286813   22.342523   19.484119
# min     -1.000000    0.000000   50.000000
# 25%     40.000000   25.000000  100.000000
# 50%     90.000000   25.000000  110.000000
# ...

# %%
# get cereals with highest and lowest nutritional values
highest_content = {}
for attribute in nutritional_cols:
    max_cereal= df.loc[df[attribute].idxmax()]['name']
    highest_content[attribute]= max_cereal
    
lowest_content = {}
for attribute in nutritional_cols:
    min_cereal= df.loc[df[attribute].idxmin()]['name']
    lowest_content[attribute]= min_cereal

# %%
highest_content
# Out:
# {'protein': 'Cheerios',
#  'fat': '100% Natural Bran',
#  'sodium': 'Product 19',
#  'fiber': 'All-Bran with Extra Fiber',
#  'carbo': 'Rice Chex',
#  'sugars': 'Golden Crisp',
#  'potass': 'All-Bran with Extra Fiber',
#  'vitamins': 'Just Right Crunchy  Nuggets',
#  'calories': 'Mueslix Crispy Blend'}

# %%
lowest_content
# Out:
# {'protein': "Cap'n'Crunch",
#  'fat': 'All-Bran with Extra Fiber',
#  'sodium': 'Frosted Mini-Wheats',
#  'fiber': "Cap'n'Crunch",
#  'carbo': 'Quaker Oatmeal',
#  'sugars': 'Quaker Oatmeal',
#  'potass': 'Almond Delight',
#  'vitamins': '100% Natural Bran',
#  'calories': 'All-Bran with Extra Fiber'}

# %%
# since there are only 3 hot cereals, comparison will not stand any value
# just finding the hot cereals
df[df.type =='H']
# Out:
#                       name mfr type  calories  protein  fat  sodium  fiber  \
# 20  Cream of Wheat (Quick)   N    H       100        3    0      80    1.0
# 43                   Maypo   A    H       100        4    1       0    0.0
# 57          Quaker Oatmeal   Q    H       100        5    2       0    2.7
#
#     carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 20   21.0       0      -1         0      2     1.0  1.00  64.533816
# 43   16.0       3      95        25      2     1.0  1.00  54.850917
# 57   -1.0      -1     110         0      1     1.0  0.67  50.828392

# %%
# Determine the average rating of cereals placed on each shelf (1, 2, or 3).
df.shelf.value_counts()
# Out:
# 3    36
# 2    21
# 1    20
# Name: shelf, dtype: int64

# %%
for sh in df.shelf.unique().tolist():
    print(f'Average rating for shelf {sh}: {df[df.shelf == sh].rating.mean()}')
# Out:
# Average rating for shelf 3: 45.220032
# Average rating for shelf 1: 46.14543875
# Average rating for shelf 2: 34.97282652380953

# %% [markdown]
# ## Working on sugars

# %% [markdown]
# ### calculating the avg of sugars

# %%
# Identify cereals with high sugar content.
# find the average sugar content, max and min sugar content
print(f'Avg Sugars:', df.sugars.mean())
print(f'Max Sugars :', df.sugars.max())
print(f'Min Sugars:', df.sugars.min())
# Out:
# Avg Sugars: 6.922077922077922
# Max Sugars : 15
# Min Sugars: -1

# %%
# lets consider range between 10 to 15 be HIGH
high_sugar= df[(df.sugars >= 10) & (df.sugars <= 15)]
high_sugar
# Out:
#                                       name mfr type  calories  protein  fat  \
# 5                  Apple Cinnamon Cheerios   G    C       110        2    2
# 6                              Apple Jacks   K    C       110        2    0
# 10                            Cap'n'Crunch   Q    C       120        1    2
# 14                             Cocoa Puffs   G    C       110        1    1
# 17                               Corn Pops   K    C       110        1    0
# 18                           Count Chocula   G    C       110        1    1
# 22                  Crispy Wheat & Raisins   G    C       100        2    1
# 24                             Froot Loops   K    C       110        2    1
# 25                          Frosted Flakes   K    C       110        1    0
# 27  Fruit & Fibre Dates; Walnuts; and Oats   P    C       120        3    2
# 28                           Fruitful Bran   K    C       120        3    0
# ...

# %%
# categorize which manufacturer has high sugar content in them
high_sugar.mfr.value_counts()
# Out:
# G    9
# K    8
# P    5
# Q    2
# R    2
# Name: mfr, dtype: int64

# %%
high_sugar.type.value_counts()
# Out:
# C    26
# Name: type, dtype: int64

# %%
# certainly low rating for high sugar content
high_sugar.rating.describe()
# Out:
# count    26.000000
# mean     31.223459
# std       5.929810
# min      18.042851
# 25%      28.167520
# 50%      31.151135
# 75%      35.650204
# max      41.015492
# Name: rating, dtype: float64

# %% [markdown]
# ### high sugar content cereals which one's got the lowest rating and the highest rating

# %%
# lowest one
high_sugar[high_sugar.rating == high_sugar.rating.min()]
# Out:
#             name mfr type  calories  protein  fat  sodium  fiber  carbo  \
# 10  Cap'n'Crunch   Q    C       120        1    2     220    0.0   12.0
#
#     sugars  potass  vitamins  shelf  weight  cups     rating
# 10      12      35        25      2     1.0  0.75  18.042851

# %%
# highest ones
high_sugar[high_sugar.rating == high_sugar.rating.max()]
# Out:
#              name mfr type  calories  protein  fat  sodium  fiber  carbo  \
# 28  Fruitful Bran   K    C       120        3    0     240    5.0   14.0
#
#     sugars  potass  vitamins  shelf  weight  cups     rating
# 28      12     190        25      3    1.33  0.67  41.015492

# %%
# Find the cereals with the highest and lowest ratings
min_rating_cereal = high_sugar[high_sugar.rating == high_sugar.rating.min()]
max_rating_cereal = high_sugar[high_sugar.rating == high_sugar.rating.max()]

# Plotting with Matplotlib
fig, ax = plt.subplots(figsize=(8, 5))

# Scatter plot for all cereals
ax.scatter(high_sugar['sugars'], high_sugar['rating'], color='blue', label='All Cereals')

# Highlight the cereals with min and max ratings
ax.scatter(min_rating_cereal['sugars'], min_rating_cereal['rating'], color='red', label='Lowest Rated', s=100, edgecolor='black')
ax.scatter(max_rating_cereal['sugars'], max_rating_cereal['rating'], color='green', label='Highest Rated', s=100, edgecolor='black')

# Add labels and title
ax.set_xlabel('Sugar level')
ax.set_ylabel('Rating')
ax.set_title('High Sugar level Cereals Ratings')
ax.legend()

plt.show()

# %% [markdown]
# ## Working on potass & sodium

# %%
# Investigate the levels of potassium and sodium in cereals.
df[['potass','sodium']].describe()
# Out:
#            potass      sodium
# count   77.000000   77.000000
# mean    96.077922  159.675325
# std     71.286813   83.832295
# min     -1.000000    0.000000
# 25%     40.000000  130.000000
# 50%     90.000000  180.000000
# 75%    120.000000  210.000000
# max    330.000000  320.000000

# %% [markdown]
# ## calculating the avg of potass & sodium

# %%
# average potassium content is 96, so lets set the high range to be greater than 96
# average sodium content is 159 , so lets set the lower range to 0 to 159
healthy_products =df[(df.sodium <= 159) & (df.potass >= 96)]
healthy_products
# Out:
#                                  name mfr type  calories  protein  fat  \
# 0                           100% Bran   N    C        70        4    1
# 1                   100% Natural Bran   Q    C       120        3    5
# 3           All-Bran with Extra Fiber   K    C        50        4    0
# 13                           Clusters   G    C       110        3    2
# 19                 Cracklin' Oat Bran   K    C       110        3    3
# 22             Crispy Wheat & Raisins   G    C       100        2    1
# 26                Frosted Mini-Wheats   K    C       100        3    0
# 34                 Great Grains Pecan   P    C       120        3    3
# 44   Muesli Raisins; Dates; & Almonds   R    C       150        4    3
# 45  Muesli Raisins; Peaches; & Pecans   R    C       150        4    3
# 46               Mueslix Crispy Blend   K    C       160        3    2
# 56                 Quaker Oat Squares   Q    C       100        4    1
# ...

# %% [markdown]
# ### high sugar content cereals which one's got the lowest potass and the highest potass

# %%
# Lowest ones
healthy_products[healthy_products.potass == healthy_products.potass.min()]
# Out:
#                    name mfr type  calories  protein  fat  sodium  fiber  \
# 26  Frosted Mini-Wheats   K    C       100        3    0       0    3.0
# 34   Great Grains Pecan   P    C       120        3    3      75    3.0
#
#     carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 26   14.0       7     100        25      2     1.0  0.80  58.345141
# 34   13.0       4     100        25      3     1.0  0.33  45.811716

# %%
# highest ones
healthy_products[healthy_products.potass == healthy_products.potass.max()]
# Out:
#                         name mfr type  calories  protein  fat  sodium  fiber  \
# 3  All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
#
#    carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 3    8.0       0     330        25      3     1.0   0.5  93.704912

# %%
# Find cereals with the lowest and highest potassium content
min_potass_cereal = healthy_products[healthy_products.potass == healthy_products.potass.min()]
max_potass_cereal = healthy_products[healthy_products.potass == healthy_products.potass.max()]

# Plotting with Matplotlib
fig, ax = plt.subplots(figsize=(8, 5))

# Scatter plot for all cereals
ax.scatter(healthy_products['sugars'], healthy_products['potass'], color='blue', label='All Cereals')

# Highlight the cereals with min and max potassium
ax.scatter(min_potass_cereal['sugars'], min_potass_cereal['potass'], color='red', label='Lowest Potassium', s=100, edgecolor='black')
ax.scatter(max_potass_cereal['sugars'], max_potass_cereal['potass'], color='green', label='Highest Potassium', s=100, edgecolor='black')

# Add labels and title
ax.set_xlabel('Sugar Content')
ax.set_ylabel('Potassium Content')
ax.set_title('High Sugar Cereals Potassium Content')
ax.legend()

plt.show()

# %% [markdown]
# ### high sugar content cereals which one's got the lowest sodium and the highest sodium

# %%
# Lowest ones
healthy_products[healthy_products.sodium == healthy_products.sodium.min()]
# Out:
#                          name mfr type  calories  protein  fat  sodium  fiber  \
# 26        Frosted Mini-Wheats   K    C       100        3    0       0    3.0
# 57             Quaker Oatmeal   Q    H       100        5    2       0    2.7
# 60             Raisin Squares   K    C        90        2    0       0    2.0
# 64     Shredded Wheat 'n'Bran   N    C        90        3    0       0    4.0
# 65  Shredded Wheat spoon size   N    C        90        3    0       0    3.0
#
#     carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 26   14.0       7     100        25      2     1.0  0.80  58.345141
# 57   -1.0      -1     110         0      1     1.0  0.67  50.828392
# 60   15.0       6     110        25      3     1.0  0.50  55.333142
# 64   19.0       0     140         0      1     1.0  0.67  74.472949
# 65   20.0       0     120         0      1     1.0  0.67  72.801787

# %%
# highest ones
healthy_products[healthy_products.sodium == healthy_products.sodium.max()]
# Out:
#                                  name mfr type  calories  protein  fat  \
# 45  Muesli Raisins; Peaches; & Pecans   R    C       150        4    3
# 46               Mueslix Crispy Blend   K    C       160        3    2
#
#     sodium  fiber  carbo  sugars  potass  vitamins  shelf  weight  cups  \
# 45     150    3.0   16.0      11     170        25      3     1.0  1.00
# 46     150    3.0   17.0      13     160        25      3     1.5  0.67
#
#        rating
# 45  34.139765
# 46  30.313351

# %%
# Find cereals with the lowest and highest sodium content
min_sodium_cereal = healthy_products[healthy_products.sodium == healthy_products.sodium.min()]
max_sodium_cereal = healthy_products[healthy_products.sodium == healthy_products.sodium.max()]

# Seaborn Scatter Plot
plt.figure(figsize=(8, 5))
sns.scatterplot(data=healthy_products, x='sugars', y='sodium', color='blue', label='All Cereals')

# Highlight cereals with min and max sodium
sns.scatterplot(data=min_sodium_cereal, x='sugars', y='sodium', color='red', label='Lowest Sodium', s=150, edgecolor='black')
sns.scatterplot(data=max_sodium_cereal, x='sugars', y='sodium', color='green', label='Highest Sodium', s=150, edgecolor='black')

# Add labels and title
plt.xlabel('Sugar Content')
plt.ylabel('Sodium Content')
plt.title('High Sugar Cereals Sodium Content')
plt.legend()

plt.show()

# %%
# numeric statistics rating for these healthy options
healthy_products.rating.describe()
# Out:
# count    17.000000
# mean     50.677360
# std      17.709424
# min      30.313351
# 25%      37.136863
# 50%      45.811716
# 75%      58.345141
# max      93.704912
# Name: rating, dtype: float64

# %%
# manufacturer counts for the healthy options
healthy_products.mfr.value_counts() # Kelloggs leading the way
# Out:
# K    5
# N    3
# Q    3
# G    3
# R    2
# P    1
# Name: mfr, dtype: int64

# %%
df.vitamins.describe()
# Out:
# count     77.000000
# mean      28.246753
# std       22.342523
# min        0.000000
# 25%       25.000000
# 50%       25.000000
# 75%       25.000000
# max      100.000000
# Name: vitamins, dtype: float64

# %% [markdown]
# ### Brands & Their Ratings

# %%
df_sorted = df.sort_values(by='rating', ascending=False)

plt.figure(figsize=(14, 5))
plt.title("Brands and Their Ratings")
plt.xticks(rotation = 90)
sns.barplot(data=df_sorted, x=df_sorted['name'], y=df_sorted['rating'])
# Out:
# <Axes: title={'center': 'Brands and Their Ratings'}, xlabel='name', ylabel='rating'>

# %%
# Basic histogram with a clean layout
plt.figure(figsize=(8, 5))
sns.histplot(df['sugars'], kde=True, bins=20, color='grey', alpha=0.6)

# Add title and labels
plt.title('Sugar Content Distribution in Cereals', fontsize=14)
plt.xlabel('Sugar Content (g)', fontsize=12)
plt.ylabel('Frequency', fontsize=12)

# Add simple threshold lines
plt.axvline(15, color='red', linestyle='--', label='High Sugar (15g+)', linewidth=1.2)
plt.axvline(5, color='green', linestyle='--', label='Low Sugar (<5g)', linewidth=1.2)

# Add legend
plt.legend()

# Display plot
plt.tight_layout()
plt.show()

# %%
numeric_columns = df.drop(columns=['name', 'type', 'mfr','shelf', 'cups', 'weight'])

correlation_matrix = numeric_columns.corr(method = 'pearson')

# Create a heatmap for correlation with 'rating'
plt.figure(figsize=(8, 5))
sns.heatmap(correlation_matrix[['rating']].sort_values(by='rating', ascending=False), annot=True)
plt.title("Correlation Heatmap with Ratings")
plt.show()

# %%
# Correlation matrix
plt.figure(figsize=(10, 8))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()
